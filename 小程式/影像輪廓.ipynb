# %%
from PIL import Image, ImageFilter
import matplotlib.pyplot as plt

# %% [markdown]
# ## 影像輪廓獲取

# %%
img=Image.open('fertilization.png')
omg=img.filter(ImageFilter.CONTOUR)
omg.save('birdnestContour.png')
plt.imshow(img)
plt.axis('off')
plt.show()
plt.imshow(omg)
plt.axis('off')
plt.show()
