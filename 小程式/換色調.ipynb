# %%
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# ## 把照片的RGB調換

# %%
img=Image.open('cat03.jpg')
r,g,b=img.split()
omg=Image.merge("RGB",(b,g,r))
plt.imshow(img)
plt.axis('off')
plt.show()
plt.imshow(omg)
plt.axis('off')
plt.show()
